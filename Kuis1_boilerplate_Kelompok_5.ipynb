# %% [markdown]
# <a href="https://colab.research.google.com/github/reysilvaa/machine-learning/blob/main/Kuis1_boilerplate_Kelompok_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
#
# Pada kuis ini, Anda diminta untuk melakukan klasifikasi citra wajah dengan menggunakan dataset Labeled Face in Wild (LFW).
# Spesifikasi pengerjaan kuis yang harus dipehuni adalah,
#
# 1. Setiap label dari dataset LFW harus berisikan minimal 10 gambar (5 poin)
# 2. Citra yang digunakan merupakan citra RGB / color (5 poin)
# 3. (Opsional) Lakukan proses pra pengolahan data jika diperlukan (ekstra 10 poin)
# 4. (Wajib) Gunakan fitur histogram untuk setiap channel citra (35 poin)
# 5. (Wajib) Gunakan algoritma SVM sebagai model dasar (35 poin)
# 6. (Wajib) Gunakan metric akurasi, dan *classification report* untuk melihat performa model (20 poin)
#
# ## Challenge
# Setelah menyelesaikan kuis berdasarkan spesifikasi wajib, Anda diperkenankan untuk
#
# - Menggunakan fitur lain selain histogram (ekstra 20 poin)
# - Menggunakan model lain selain SVM (ekstra 10 poin)
# - Evalusi dengan metric lain ataupun report dengan *confusion matrix* (ekstra 10 poin)

# %% [markdown]
# # Boilerplate
#
# Berikut merupakan boilerplate code yang dapat Anda gunakan sebagai acuan dasar pengerjaan kuis.
# Anda diperkenankan untuk **menambah** ataupun **mengurangi** bagian boilerplate yang disediakan.

# %% [markdown]
# ---

# %% [markdown]
# # Preparation

# %%
# Load required library
# Import Required Library
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Load Data

# %%
# Load Dataset
# We will load dataset only for faces with contain min 10 images
# We also want to keep images in color; color=True

faces = fetch_lfw_people(min_faces_per_person=10, color=True)

# Check Faces
print(f'Total Label: {len(faces.target_names)}')
print(f'Data dimension: {faces.images.shape}')
print(f'Images flatten dimension: {faces.data.shape}')
# Out:
# Total Label: 158
# Data dimension: (4324, 62, 47, 3)
# Images flatten dimension: (4324, 8742)

# %%
# Check by Plotted Images
# Generate random 15 images
rand_labels = [np.random.randint(0, len(faces.data)) for x in range(0, 15)]

fig, ax = plt.subplots(3, 5)
fig.tight_layout()
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[rand_labels[i]], cmap='bone')
    axi.set(xticks=[], yticks=[],
            xlabel=faces.target_names[faces.target[rand_labels[i]]])

# %% [markdown]
# # Preprocessing

# %%
# Normalisasi citra
X_normalized = faces.data / 255.0  # Mengubah nilai pixel ke rentang [0, 1]
y = faces.target  # Label

# %% [markdown]
# # Features Extraction

# %%
# Fungsi untuk menampilkan citra
def display_image(image, label):
    plt.imshow(image)
    plt.axis('off')  # Matikan sumbu
    plt.title(label)  # Tampilkan label di atas citra
    plt.show()

# Fungsi untuk menampilkan histogram untuk setiap channel RGB
def plot_histogram(image):
    plt.figure(figsize=(10, 5))
    colors = ('r', 'g', 'b')

    # Menghitung histogram untuk setiap channel
    for i, color in enumerate(colors):
        hist, bins = np.histogram(image[:, :, i] * 255, bins=256, range=(0, 256))
        plt.plot(bins[:-1], hist, color=color, label=f'{color.upper()} Channel')

    plt.title('Histogram untuk Setiap Channel RGB')
    plt.xlabel('Intensitas Pixel')
    plt.ylabel('Frekuensi')
    plt.legend()
    plt.xlim([0, 255])
    plt.ylim([0, np.max(hist) * 1.1])  # Batas y sesuai dengan nilai maksimum histogram
    plt.grid()
    plt.show()

# Ambil citra pertama
image = faces.images[rand_labels[0]]  # Ambil citra pertama
label = faces.target_names[faces.target[rand_labels[0]]]
# Tampilkan citra untuk memastikan validitas
display_image(image, label)

# Jalankan fungsi histogram untuk citra yang dipilih
plot_histogram(image)

# %% [markdown]
# # Build Model

# %%
'''
    Pada bagian ini lakukan proses pembuatan model,

    1. Pembuatan data training dan data testing
    2. Pembuatan objek model
    3. Proses fitting model
'''
# Membagi data menjadi data latih dan uji
X_train, X_test, y_train, y_test = train_test_split(X_normalized, faces.target, test_size=0.3, random_state=42)

# Membuat model SVM
model = SVC(kernel='linear', random_state=42)
model.fit(X_train, y_train)

# Inisialisasi dan latih model SVM
svm_model = SVC(kernel='rbf', random_state=42)
svm_model.fit(X_train, y_train)

# Definisikan parameter grid
# Karena hasil predict yang rendah saya cari cara lain agar accuracy meningkat
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.1, 1, 10],
    'kernel': ['linear', 'rbf']
}

# Inisialisasi GridSearchCV
grid_search = GridSearchCV(SVC(), param_grid, refit=True, verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=  42.3s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=  43.3s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=  43.5s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=  42.5s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=  42.5s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=  42.6s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=  42.4s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=  42.5s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=  42.8s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=  42.1s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=  49.3s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=  49.4s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=  49.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=  50.1s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=  49.4s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  43.1s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  43.0s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  43.1s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  42.8s
# [CV] END ....................C=0.1, gamma=0.1, kernel=linear; total time=  43.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  48.9s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  50.3s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  49.9s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  49.7s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=  52.7s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  42.9s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  42.9s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  42.8s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  43.4s
# [CV] END ......................C=0.1, gamma=1, kernel=linear; total time=  44.1s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  52.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  52.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  50.8s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  50.2s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=  50.5s
# [CV] END .....................C=0.1, gamma=10, kernel=linear; total time=  42.0s
# [CV] END .....................C=0.1, gamma=10, kernel=linear; total time=  41.7s
# [CV] END .....................C=0.1, gamma=10, kernel=linear; total time=  41.7s
# [CV] END .....................C=0.1, gamma=10, kernel=linear; total time=  42.3s
# [CV] END .....................C=0.1, gamma=10, kernel=linear; total time=  42.8s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=  59.9s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=  59.4s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=  51.3s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=  50.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=  51.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=  51.0s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=  50.1s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=  50.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=  49.3s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=  54.9s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=  55.4s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=  51.9s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=  48.7s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=  49.4s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=  48.6s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=  50.0s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=  48.3s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=  50.3s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=  51.4s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=  50.3s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=  50.5s
# [CV] END ......................C=1, gamma=0.1, kernel=linear; total time=  50.9s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  50.4s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  50.9s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  50.8s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  49.7s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=  50.8s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=  49.9s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=  49.7s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=  50.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=  48.9s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=  50.1s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  58.5s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  58.9s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  59.3s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  58.7s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=  58.7s
# [CV] END .......................C=1, gamma=10, kernel=linear; total time=  50.3s
# [CV] END .......................C=1, gamma=10, kernel=linear; total time=  48.8s
# [CV] END .......................C=1, gamma=10, kernel=linear; total time=  50.2s
# [CV] END .......................C=1, gamma=10, kernel=linear; total time=  49.5s
# [CV] END .......................C=1, gamma=10, kernel=linear; total time=  49.8s
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ..........................C=1, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  54.6s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  54.5s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  54.3s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  54.6s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=  54.2s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  53.8s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  54.4s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  53.7s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  54.0s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=  54.7s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=  49.7s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=  49.3s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=  50.6s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=  48.7s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=  49.6s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=  58.0s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=  54.5s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=  55.9s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=  54.5s
# [CV] END .....................C=10, gamma=0.1, kernel=linear; total time=  54.1s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time= 1.0min
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time= 1.0min
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  59.5s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  59.7s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=  59.6s
# [CV] END .......................C=10, gamma=1, kernel=linear; total time=  55.1s
# [CV] END .......................C=10, gamma=1, kernel=linear; total time=  56.4s
# [CV] END .......................C=10, gamma=1, kernel=linear; total time=  56.4s
# [CV] END .......................C=10, gamma=1, kernel=linear; total time=  56.5s
# [CV] END .......................C=10, gamma=1, kernel=linear; total time=  55.8s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time= 1.1min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time= 1.1min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time= 1.1min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time= 1.0min
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time= 1.1min
# [CV] END ......................C=10, gamma=10, kernel=linear; total time=  55.4s
# [CV] END ......................C=10, gamma=10, kernel=linear; total time=  55.4s
# [CV] END ......................C=10, gamma=10, kernel=linear; total time=  55.6s
# [CV] END ......................C=10, gamma=10, kernel=linear; total time=  56.7s
# [CV] END ......................C=10, gamma=10, kernel=linear; total time=  54.7s
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END .........................C=10, gamma=10, kernel=rbf; total time= 1.0min
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=  56.1s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=  57.2s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=  55.6s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=  55.8s
# [CV] END ..................C=100, gamma=scale, kernel=linear; total time=  54.8s
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END .....................C=100, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=  54.1s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=  55.9s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=  54.4s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=  54.1s
# [CV] END ...................C=100, gamma=auto, kernel=linear; total time=  53.9s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=  48.6s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=  50.0s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=  52.6s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=  52.0s
# [CV] END ......................C=100, gamma=auto, kernel=rbf; total time=  51.9s
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time=  58.6s
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time=  57.4s
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time=  56.1s
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time=  56.4s
# [CV] END ....................C=100, gamma=0.1, kernel=linear; total time=  53.6s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time= 1.0min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time= 1.1min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time= 1.0min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time= 1.0min
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time= 1.0min
# [CV] END ......................C=100, gamma=1, kernel=linear; total time=  54.7s
# [CV] END ......................C=100, gamma=1, kernel=linear; total time=  54.5s
# [CV] END ......................C=100, gamma=1, kernel=linear; total time=  55.4s
# [CV] END ......................C=100, gamma=1, kernel=linear; total time=  56.1s
# [CV] END ......................C=100, gamma=1, kernel=linear; total time=  55.6s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time= 1.0min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time= 1.0min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time= 1.1min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time= 1.0min
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time= 1.0min
# [CV] END .....................C=100, gamma=10, kernel=linear; total time=  57.3s
# [CV] END .....................C=100, gamma=10, kernel=linear; total time=  57.6s
# [CV] END .....................C=100, gamma=10, kernel=linear; total time=  57.1s
# [CV] END .....................C=100, gamma=10, kernel=linear; total time=  54.7s
# [CV] END .....................C=100, gamma=10, kernel=linear; total time=  54.3s
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time= 1.1min
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time= 1.1min
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time= 1.1min
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time= 1.1min
# [CV] END ........................C=100, gamma=10, kernel=rbf; total time= 1.1min
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': ['scale', 'auto', 0.1, 1, 10],
#                          'kernel': ['linear', 'rbf']},
#              verbose=2)

# %% [markdown]
# # Evaluation

# %%
'''
    Pada bagian ini, lakukan evaluasi terhadap data training dan data testing
    dengan menggunakan metric akurasi dan juga classfication report

    Hints:
        Anda dapat menggunakan referensi Jobseet 4 Percobaan 5
'''
# Gunakan model terbaik
svm_model = grid_search.best_estimator_

# Prediksi dan evaluasi lagi
y_pred = svm_model.predict(X_test)

# Hitung akurasi
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi: {accuracy:.2f}")

# Buat classification report dengan zero_division=1
report = classification_report(y_test, y_pred, target_names=faces.target_names, zero_division=1)
print("\nClassification Report:")
print(report)

# Visualisasikan confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=faces.target_names, yticklabels=faces.target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Akurasi: 0.51
#
# Classification Report:
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       1.00      0.67      0.80         6
#              Adrien Brody       0.25      0.50      0.33         2
#          Alejandro Toledo       0.21      0.43      0.29         7
#              Alvaro Uribe       0.50      0.73      0.59        11
#           Amelie Mauresmo       0.83      0.71      0.77         7
#              Andre Agassi       0.19      1.00      0.32         4
#              Andy Roddick       1.00      0.20      0.33         5
#            Angelina Jolie       0.00      0.00      0.00         3
#               Ann Veneman       0.50      0.33      0.40         3
#           Anna Kournikova       0.00      0.00      0.00         3
#               Salma Hayek       0.25      0.25      0.25         4
#           Serena Williams       0.58      0.78      0.67        18
#             Sergey Lavrov       0.33      0.25      0.29         4
#    Sergio Vieira De Mello       0.00      0.00      0.00         5
#         Silvio Berlusconi       0.12      0.11      0.12         9
#           Spencer Abraham       0.25      0.20      0.22         5
#       Taha Yassin Ramadan       1.00      0.00      0.00         4
#              Tang Jiaxuan       1.00      0.25      0.40         4
#               Tiger Woods       0.25      0.10      0.14        10
#                Tim Henman       0.11      0.20      0.14         5
#                Tom Cruise       1.00      0.67      0.80         3
#               Tom Daschle       0.50      0.40      0.44         5
#                 Tom Hanks       0.00      0.00      0.00         1
#                 Tom Ridge       0.50      0.60      0.55        10
#              Tommy Franks       1.00      0.00      0.00         9
#            Tommy Thompson       1.00      0.00      0.00         4
#                Tony Blair       0.55      0.78      0.65        40
#                Trent Lott       0.75      0.60      0.67         5
#            Venus Williams       0.14      0.17      0.15         6
#               Vicente Fox       0.62      0.50      0.56        10
#            Vladimir Putin       0.29      0.50      0.36        12
#            Walter Mondale       0.50      0.33      0.40         3
#                Wen Jiabao       0.75      0.50      0.60         6
#              Winona Ryder       0.20      0.50      0.29         2
#          Yoriko Kawaguchi       1.00      0.50      0.67         4
#
#                  accuracy                           0.51      1298
#                 macro avg       0.57      0.35      0.37      1298
#              weighted avg       0.58      0.51      0.48      1298

# %%
## Challenge Section

from skimage.feature import hog

# Fungsi untuk mengekstrak HOG dari setiap channel warna
def extract_hog_features_per_channel(image):
    hog_features = []
    for channel in range(image.shape[2]):  # Iterasi per channel (R, G, B)
        feature = hog(image[:, :, channel], orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2))
        hog_features.append(feature)
    return np.concatenate(hog_features)  # Gabungkan fitur dari setiap channel

# Ekstraksi HOG untuk semua gambar dalam dataset
def extract_hog_features(images):
    return np.array([extract_hog_features_per_channel(image) for image in images])

# Ekstrak fitur HOG dari dataset LFW
hog_features = extract_hog_features(faces.images)

# %%
# 2. Menggunakan model Random Forest
# Bagi data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(hog_features, faces.target, test_size=0.3, random_state=42)

# Normalisasi fitur
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Inisialisasi dan latih model Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)

# Prediksi menggunakan set pengujian
y_pred = rf_model.predict(X_test_scaled)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi: {accuracy:.2f}")

# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Generate classification report with zero_division=1
print(classification_report(y_test, y_pred, target_names=faces.target_names, zero_division=1))

# Visualize confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=faces.target_names, yticklabels=faces.target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# Akurasi: 0.24
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       1.00      0.00      0.00         6
#              Adrien Brody       1.00      0.00      0.00         2
#          Alejandro Toledo       0.75      0.43      0.55         7
#              Alvaro Uribe       1.00      0.00      0.00        11
#           Amelie Mauresmo       1.00      0.00      0.00         7
#              Andre Agassi       1.00      0.00      0.00         4
#              Andy Roddick       1.00      0.00      0.00         5
#            Angelina Jolie       1.00      0.00      0.00         3
#               Ann Veneman       1.00      0.00      0.00         3
#            Saddam Hussein       1.00      0.00      0.00         8
#               Salma Hayek       1.00      0.00      0.00         4
#           Serena Williams       0.50      0.11      0.18        18
#             Sergey Lavrov       1.00      0.00      0.00         4
#    Sergio Vieira De Mello       1.00      0.00      0.00         5
#         Silvio Berlusconi       1.00      0.00      0.00         9
#           Spencer Abraham       1.00      0.00      0.00         5
#       Taha Yassin Ramadan       1.00      0.00      0.00         4
#              Tang Jiaxuan       1.00      0.00      0.00         4
#               Tiger Woods       0.00      0.00      0.00        10
#                Tim Henman       1.00      0.00      0.00         5
#                Tom Cruise       1.00      0.00      0.00         3
#               Tom Daschle       1.00      0.00      0.00         5
#                 Tom Hanks       1.00      0.00      0.00         1
#                 Tom Ridge       1.00      0.00      0.00        10
#              Tommy Franks       1.00      0.00      0.00         9
#            Tommy Thompson       1.00      0.00      0.00         4
#                Tony Blair       0.29      0.60      0.39        40
#                Trent Lott       1.00      0.00      0.00         5
#            Venus Williams       1.00      0.00      0.00         6
#               Vicente Fox       1.00      0.00      0.00        10
#            Vladimir Putin       0.00      0.00      0.00        12
#            Walter Mondale       1.00      0.00      0.00         3
#                Wen Jiabao       1.00      0.00      0.00         6
#              Winona Ryder       1.00      0.00      0.00         2
#          Yoriko Kawaguchi       1.00      0.00      0.00         4
#
#                  accuracy                           0.24      1298
#                 macro avg       0.85      0.05      0.05      1298
#              weighted avg       0.64      0.24      0.14      1298

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# Menggunakan HOG features yang telah diekstraksi sebagai X dan label wajah sebagai y
X = hog_features
y = faces.target

# Multinomial Naive Bayes
mnb = MultinomialNB()

# Bagi data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalisasi fitur
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Latih model Naive Bayes dengan data terlatih
mnb.fit(X_train, y_train)

# Prediksi menggunakan set pengujian
y_pred = mnb.predict(X_test_scaled)

# Menghitung akurasi
accuracy = accuracy_score(y_test, y_pred)
print(f"Akurasi: {accuracy:.2f}")

# Mencetak laporan klasifikasi
print(classification_report(y_test, y_pred, target_names=faces.target_names, zero_division=1))
# Out:
# Akurasi: 0.27
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       0.20      0.17      0.18         6
#              Adrien Brody       0.12      0.50      0.20         2
#          Alejandro Toledo       0.40      0.29      0.33         7
#              Alvaro Uribe       0.60      0.27      0.38        11
#           Amelie Mauresmo       0.50      0.29      0.36         7
#              Andre Agassi       0.11      0.50      0.17         4
#              Andy Roddick       1.00      0.00      0.00         5
#            Angelina Jolie       0.00      0.00      0.00         3
#               Ann Veneman       1.00      0.33      0.50         3
#           Anna Kournikova       0.33      0.33      0.33         3
#             Ari Fleischer       0.00      0.00      0.00         5
#              Ariel Sharon       0.37      0.55      0.44        20
#     Arnold Schwarzenegger       1.00      0.05      0.09        21
#      Atal Bihari Vajpayee       1.00      0.50      0.67         2
#              Bill Clinton       1.00      0.20      0.33        10
#                Bill Gates       0.14      0.17      0.15         6
#              Bill McBride       1.00      0.00      0.00         3
#                Bill Simon       1.00      0.50      0.67         2
#            Britney Spears       0.04      0.17      0.07         6
#              Carlos Menem       0.00      0.00      0.00         5
#                Tom Cruise       0.00      0.00      0.00         3
#               Tom Daschle       0.15      0.40      0.22         5
#                 Tom Hanks       0.00      0.00      0.00         1
#                 Tom Ridge       1.00      0.20      0.33        10
#              Tommy Franks       0.00      0.00      0.00         9
#            Tommy Thompson       1.00      0.00      0.00         4
#                Tony Blair       0.83      0.38      0.52        40
#                Trent Lott       1.00      0.00      0.00         5
#            Venus Williams       0.44      0.67      0.53         6
#               Vicente Fox       1.00      0.00      0.00        10
#            Vladimir Putin       0.58      0.58      0.58        12
#            Walter Mondale       1.00      0.00      0.00         3
#                Wen Jiabao       1.00      0.17      0.29         6
#              Winona Ryder       0.00      0.00      0.00         2
#          Yoriko Kawaguchi       1.00      0.00      0.00         4
#
#                  accuracy                           0.27      1298
#                 macro avg       0.49      0.22      0.19      1298
#              weighted avg       0.58      0.27      0.29      1298

# %%
# Gaussian Naive Bayes
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f"Akurasi: {accuracy:.2f}")

print(classification_report(y_test, y_pred, target_names=faces.target_names, zero_division=1))
# Out:
# Akurasi: 0.39
#                            precision    recall  f1-score   support
#
#              Abdullah Gul       0.50      0.67      0.57         6
#              Adrien Brody       1.00      0.00      0.00         2
#          Alejandro Toledo       0.36      0.71      0.48         7
#              Alvaro Uribe       0.40      0.36      0.38        11
#           Amelie Mauresmo       1.00      0.57      0.73         7
#              Andre Agassi       0.07      0.75      0.13         4
#              Andy Roddick       1.00      0.20      0.33         5
#            Angelina Jolie       0.00      0.00      0.00         3
#               Ann Veneman       1.00      0.33      0.50         3
#           Anna Kournikova       1.00      0.33      0.50         3
#             Ari Fleischer       1.00      0.00      0.00         5
#              Ariel Sharon       0.30      0.65      0.41        20
#     Arnold Schwarzenegger       0.50      0.14      0.22        21
#      Atal Bihari Vajpayee       0.20      0.50      0.29         2
#              Bill Clinton       0.29      0.20      0.24        10
#                Bill Gates       0.75      0.50      0.60         6
#              Bill McBride       1.00      0.00      0.00         3
#                Bill Simon       0.33      0.50      0.40         2
#            Britney Spears       1.00      0.17      0.29         6
#              Carlos Menem       0.00      0.00      0.00         5
#               Carlos Moya       0.10      0.25      0.14         4
#      Catherine Zeta-Jones       1.00      0.00      0.00         2
#             Charles Moose       1.00      0.00      0.00         5
#              Colin Powell       0.63      0.72      0.67        65
#          Condoleezza Rice       1.00      0.00      0.00         3
#             David Beckham       0.17      0.43      0.24         7
#          David Nalbandian       0.50      0.33      0.40         3
#               Dick Cheney       1.00      0.00      0.00         6
#     Dominique de Villepin       1.00      0.00      0.00         4
#           Donald Rumsfeld       0.34      0.66      0.45        32
#            Edmund Stoiber       1.00      0.00      0.00         7
#           Eduardo Duhalde       1.00      0.00      0.00         2
#              Fidel Castro       0.00      0.00      0.00         9
#            George HW Bush       1.00      0.00      0.00         4
#          George Robertson       1.00      0.50      0.67         6
#             George W Bush       0.67      0.65      0.66       172
#         Gerhard Schroeder       0.32      0.54      0.40        26
#   Gloria Macapagal Arroyo       0.42      0.50      0.45        10
